# %% [markdown]
# <a href="https://colab.research.google.com/github/mrigendra-123/hello-world/blob/master/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import face_recognition as fr

# %%
import cv2

# %%
import dlib

# %%
from google.colab import files

# %%
image = files.upload()
# Out:
#      <input type="file" id="files-a0f6de99-013c-4063-9a41-e3615c1e8f58" name="files[]" multiple disabled />
#      <output id="result-a0f6de99-013c-4063-9a41-e3615c1e8f58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving friends.jpg to friends (1).jpg

# %%
img = cv2.imread('friends.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=900x582 at 0x7F933582DBE0>

# %%
locations=fr.face_locations(img)

# %%
print(locations)
# Out:
# [(211, 550, 262, 498), (193, 262, 245, 210), (211, 667, 274, 605), (193, 348, 245, 296), (55, 400, 107, 348), (84, 564, 127, 520), (61, 607, 113, 556)]

# %%
for face in locations:
   cv2.rectangle(img,(face[3],face[0]),(face[1],face[2]),(0,255,0),2)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=900x582 at 0x7F9335891FD0>
